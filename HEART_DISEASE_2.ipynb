# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# import ML libraries
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from xgboost import XGBClassifier

# import metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix,mean_absolute_error, mean_squared_error, r2_score


# To preprocess the data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

from sklearn.impute import SimpleImputer, KNNImputer
# import iterative imputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart-2.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sex'].plot(kind='hist', bins=20, title='sex')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['cp'].plot(kind='hist', bins=20, title='cp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['trestbps'].plot(kind='hist', bins=20, title='trestbps')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='age', y='sex', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='sex', y='cp', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='cp', y='trestbps', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='trestbps', y='chol', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['exang']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('exang', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('exang')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['exang']
#   ys = series['sex']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('exang', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('exang')
# _ = plt.ylabel('sex')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['exang']
#   ys = series['cp']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('exang', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('exang')
# _ = plt.ylabel('cp')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['exang']
#   ys = series['trestbps']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('exang', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('exang')
# _ = plt.ylabel('trestbps')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['sex'].plot(kind='line', figsize=(8, 4), title='sex')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['cp'].plot(kind='line', figsize=(8, 4), title='cp')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['trestbps'].plot(kind='line', figsize=(8, 4), title='trestbps')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# Generating a statistical summary of the dataset
statistical_summary = df.describe()
statistical_summary
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# statistical_summary['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# statistical_summary['sex'].plot(kind='hist', bins=20, title='sex')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# statistical_summary['cp'].plot(kind='hist', bins=20, title='cp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# statistical_summary['trestbps'].plot(kind='hist', bins=20, title='trestbps')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# statistical_summary.plot(kind='scatter', x='age', y='sex', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# statistical_summary.plot(kind='scatter', x='sex', y='cp', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# statistical_summary.plot(kind='scatter', x='cp', y='trestbps', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# statistical_summary.plot(kind='scatter', x='trestbps', y='chol', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# statistical_summary['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# statistical_summary['sex'].plot(kind='line', figsize=(8, 4), title='sex')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# statistical_summary['cp'].plot(kind='line', figsize=(8, 4), title='cp')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# statistical_summary['trestbps'].plot(kind='line', figsize=(8, 4), title='trestbps')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
num = df['target'].value_counts()
print(num)
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
# plot
plt.figure(figsize=(10,6))
sns.countplot(x='target',data=df, palette='Set2')
plt.title('Heart Disease Frequency')
# Out:
# Text(0.5, 1.0, 'Heart Disease Frequency')

# %%
print("Percentage of patients without heart problems: "+str(round(num[0]*100/303,2)))
print("Percentage of patients with heart problems: "+str(round(num[1]*100/303,2)))
# Out:
# Percentage of patients without heart problems: 45.54
# Percentage of patients with heart problems: 54.46

# %%
max_age= df['age'].max()
min_age= df['age'].min()
print("Observation: ".upper())
print("---")
print(f"Max age of the patient: {max_age}")
print(f'Min age of the patient: {min_age}')
print(f"So, the age of the patient is between {min_age} and {max_age}")
# Out:
# OBSERVATION:
# ---
# Max age of the patient: 77
# Min age of the patient: 29
# So, the age of the patient is between 29 and 77

# %%
# plot
plt.figure(figsize=(10,6))
sns.histplot(df['age'], color='#0cc4a9', bins=50)
plt.title('Distribution of Age')
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %%
df['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
# plot
plt.figure(figsize=(10,6))
sns.countplot(x='cp',data=df, palette='Set2')
plt.title('Chest Pain Type')
# Out:
# Text(0.5, 1.0, 'Chest Pain Type')

# %%
df['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
# plot
plt.figure(figsize=(10,6))
sns.countplot(x='sex',data=df, palette='Set2')
plt.title('sex')
# Out:
# Text(0.5, 1.0, 'sex')

# %%
from sklearn.model_selection import train_test_split

predictors = df.drop("target",axis=1)
target = df["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (242, 13)

# %%
X_test.shape
# Out:
# (61, 13)

# %%
Y_train.shape
# Out:
# (242,)

# %%
Y_test.shape
# Out:
# (61,)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (61,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %

# %% [markdown]
# NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (61,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 85.25 %

# %% [markdown]
# SVM

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (61,)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 81.97 %

# %% [markdown]
# K NEAREST

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
Y_pred_knn.shape
# Out:
# (61,)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 67.21 %

# %% [markdown]
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x

#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (61,)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 81.97 %

# %% [markdown]
# RANDOM FOREST

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (61,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 83.61 %

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(11,activation='relu',input_dim=13))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 2s 4ms/step - loss: 20.2168 - accuracy: 0.4587
# Epoch 2/300
# 8/8 [==============================] - 0s 3ms/step - loss: 17.6963 - accuracy: 0.4587
# Epoch 3/300
# 8/8 [==============================] - 0s 4ms/step - loss: 15.1844 - accuracy: 0.4587
# Epoch 4/300
# 8/8 [==============================] - 0s 3ms/step - loss: 12.5283 - accuracy: 0.4628
# Epoch 5/300
# 8/8 [==============================] - 0s 4ms/step - loss: 9.7829 - accuracy: 0.4628
# Epoch 6/300
# 8/8 [==============================] - 0s 3ms/step - loss: 7.0191 - accuracy: 0.4628
# Epoch 7/300
# 8/8 [==============================] - 0s 4ms/step - loss: 5.0311 - accuracy: 0.4050
# Epoch 8/300
# 8/8 [==============================] - 0s 3ms/step - loss: 3.8577 - accuracy: 0.4215
# Epoch 9/300
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3542 - accuracy: 0.4091
# Epoch 10/300
# 8/8 [==============================] - 0s 4ms/step - loss: 2.6060 - accuracy: 0.4587
# Epoch 11/300
# 8/8 [==============================] - 0s 4ms/step - loss: 2.1218 - accuracy: 0.4711
# Epoch 12/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.7871 - accuracy: 0.4711
# Epoch 13/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.5851 - accuracy: 0.4835
# Epoch 14/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.3942 - accuracy: 0.4959
# Epoch 15/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.3229 - accuracy: 0.5248
# Epoch 16/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.2815 - accuracy: 0.5372
# Epoch 17/300
# 8/8 [==============================] - 0s 5ms/step - loss: 1.2436 - accuracy: 0.5455
# Epoch 18/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1904 - accuracy: 0.5702
# Epoch 19/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1495 - accuracy: 0.5661
# Epoch 20/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1228 - accuracy: 0.5785
# Epoch 21/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1023 - accuracy: 0.5744
# Epoch 22/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0818 - accuracy: 0.5909
# Epoch 23/300
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0587 - accuracy: 0.5744
# Epoch 24/300
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0406 - accuracy: 0.5950
# Epoch 25/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0256 - accuracy: 0.5826
# Epoch 26/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9846 - accuracy: 0.6033
# Epoch 27/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9640 - accuracy: 0.6074
# Epoch 28/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9360 - accuracy: 0.6157
# Epoch 29/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9153 - accuracy: 0.6198
# Epoch 30/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8970 - accuracy: 0.6198
# Epoch 31/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8827 - accuracy: 0.6240
# Epoch 32/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8629 - accuracy: 0.6364
# Epoch 33/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8479 - accuracy: 0.6446
# Epoch 34/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8276 - accuracy: 0.6364
# Epoch 35/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8140 - accuracy: 0.6446
# Epoch 36/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7935 - accuracy: 0.6488
# Epoch 37/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7810 - accuracy: 0.6570
# Epoch 38/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7652 - accuracy: 0.6488
# Epoch 39/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7723 - accuracy: 0.6157
# Epoch 40/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7599 - accuracy: 0.6570
# Epoch 41/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7331 - accuracy: 0.6529
# Epoch 42/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7273 - accuracy: 0.6405
# Epoch 43/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7044 - accuracy: 0.6446
# Epoch 44/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6947 - accuracy: 0.6488
# Epoch 45/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6816 - accuracy: 0.6570
# Epoch 46/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6890 - accuracy: 0.6694
# Epoch 47/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.6570
# Epoch 48/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6541 - accuracy: 0.6777
# Epoch 49/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6570 - accuracy: 0.6736
# Epoch 50/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6660 - accuracy: 0.6860
# Epoch 51/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6536 - accuracy: 0.6736
# Epoch 52/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6373 - accuracy: 0.6818
# Epoch 53/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6276 - accuracy: 0.6983
# Epoch 54/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6296 - accuracy: 0.6901
# Epoch 55/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6119 - accuracy: 0.7025
# Epoch 56/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5967 - accuracy: 0.7107
# Epoch 57/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5955 - accuracy: 0.7107
# Epoch 58/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5899 - accuracy: 0.7107
# Epoch 59/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5829 - accuracy: 0.7107
# Epoch 60/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5861 - accuracy: 0.7190
# Epoch 61/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5667 - accuracy: 0.7231
# Epoch 62/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5748 - accuracy: 0.7190
# Epoch 63/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5632 - accuracy: 0.7438
# Epoch 64/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5574 - accuracy: 0.7273
# Epoch 65/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5555 - accuracy: 0.7231
# Epoch 66/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5446 - accuracy: 0.7438
# Epoch 67/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5432 - accuracy: 0.7190
# Epoch 68/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5378 - accuracy: 0.7273
# Epoch 69/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5356 - accuracy: 0.7438
# Epoch 70/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5346 - accuracy: 0.7355
# Epoch 71/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5288 - accuracy: 0.7231
# Epoch 72/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5197 - accuracy: 0.7521
# Epoch 73/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5188 - accuracy: 0.7438
# Epoch 74/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5137 - accuracy: 0.7355
# Epoch 75/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5099 - accuracy: 0.7438
# Epoch 76/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5210 - accuracy: 0.7314
# Epoch 77/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5142 - accuracy: 0.7521
# Epoch 78/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5080 - accuracy: 0.7479
# Epoch 79/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4967 - accuracy: 0.7562
# Epoch 80/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7479
# Epoch 81/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4997 - accuracy: 0.7521
# Epoch 82/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4918 - accuracy: 0.7562
# Epoch 83/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7479
# Epoch 84/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4819 - accuracy: 0.7645
# Epoch 85/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4796 - accuracy: 0.7562
# Epoch 86/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4767 - accuracy: 0.7686
# Epoch 87/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4771 - accuracy: 0.7686
# Epoch 88/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4694 - accuracy: 0.7769
# Epoch 89/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4677 - accuracy: 0.7810
# Epoch 90/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4671 - accuracy: 0.7645
# Epoch 91/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4654 - accuracy: 0.7603
# Epoch 92/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4622 - accuracy: 0.7727
# Epoch 93/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4735 - accuracy: 0.7769
# Epoch 94/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4570 - accuracy: 0.7893
# Epoch 95/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4575 - accuracy: 0.7810
# Epoch 96/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4550 - accuracy: 0.7686
# Epoch 97/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4640 - accuracy: 0.7851
# Epoch 98/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4530 - accuracy: 0.7727
# Epoch 99/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4488 - accuracy: 0.7686
# Epoch 100/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4435 - accuracy: 0.7810
# Epoch 101/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4485 - accuracy: 0.7686
# Epoch 102/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4523 - accuracy: 0.7810
# Epoch 103/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4435 - accuracy: 0.7810
# Epoch 104/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4386 - accuracy: 0.7851
# Epoch 105/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4380 - accuracy: 0.7975
# Epoch 106/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4424 - accuracy: 0.7893
# Epoch 107/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4343 - accuracy: 0.7975
# Epoch 108/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4349 - accuracy: 0.7851
# Epoch 109/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4459 - accuracy: 0.7851
# Epoch 110/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4235 - accuracy: 0.8017
# Epoch 111/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4296 - accuracy: 0.7934
# Epoch 112/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4278 - accuracy: 0.8099
# Epoch 113/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4298 - accuracy: 0.7893
# Epoch 114/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4281 - accuracy: 0.7934
# Epoch 115/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4243 - accuracy: 0.8058
# Epoch 116/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4222 - accuracy: 0.7975
# Epoch 117/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4169 - accuracy: 0.8017
# Epoch 118/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4226 - accuracy: 0.7851
# Epoch 119/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4186 - accuracy: 0.8017
# Epoch 120/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4249 - accuracy: 0.7975
# Epoch 121/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4293 - accuracy: 0.8058
# Epoch 122/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4159 - accuracy: 0.8182
# Epoch 123/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4119 - accuracy: 0.8099
# Epoch 124/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4105 - accuracy: 0.8182
# Epoch 125/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4104 - accuracy: 0.8099
# Epoch 126/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4084 - accuracy: 0.8182
# Epoch 127/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4078 - accuracy: 0.8099
# Epoch 128/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4059 - accuracy: 0.8182
# Epoch 129/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4083 - accuracy: 0.8182
# Epoch 130/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4139 - accuracy: 0.8182
# Epoch 131/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4027 - accuracy: 0.8140
# Epoch 132/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4026 - accuracy: 0.8099
# Epoch 133/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4067 - accuracy: 0.8182
# Epoch 134/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4021 - accuracy: 0.8182
# Epoch 135/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4025 - accuracy: 0.8223
# Epoch 136/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4046 - accuracy: 0.8099
# Epoch 137/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3981 - accuracy: 0.8223
# Epoch 138/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3973 - accuracy: 0.8223
# Epoch 139/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3988 - accuracy: 0.8223
# Epoch 140/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3956 - accuracy: 0.8388
# Epoch 141/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3969 - accuracy: 0.8306
# Epoch 142/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3995 - accuracy: 0.8306
# Epoch 143/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3961 - accuracy: 0.8223
# Epoch 144/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3970 - accuracy: 0.8306
# Epoch 145/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3936 - accuracy: 0.8347
# Epoch 146/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3965 - accuracy: 0.8388
# Epoch 147/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3970 - accuracy: 0.8306
# Epoch 148/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3969 - accuracy: 0.8347
# Epoch 149/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3962 - accuracy: 0.8223
# Epoch 150/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3903 - accuracy: 0.8347
# Epoch 151/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3925 - accuracy: 0.8347
# Epoch 152/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3904 - accuracy: 0.8347
# Epoch 153/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3958 - accuracy: 0.8388
# Epoch 154/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3875 - accuracy: 0.8430
# Epoch 155/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3924 - accuracy: 0.8512
# Epoch 156/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3926 - accuracy: 0.8306
# Epoch 157/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3915 - accuracy: 0.8430
# Epoch 158/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3988 - accuracy: 0.8264
# Epoch 159/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3804 - accuracy: 0.8471
# Epoch 160/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3904 - accuracy: 0.8388
# Epoch 161/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3985 - accuracy: 0.8306
# Epoch 162/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3940 - accuracy: 0.8306
# Epoch 163/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 0.8264
# Epoch 164/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3904 - accuracy: 0.8264
# Epoch 165/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3909 - accuracy: 0.8388
# Epoch 166/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3812 - accuracy: 0.8471
# Epoch 167/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3851 - accuracy: 0.8430
# Epoch 168/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3898 - accuracy: 0.8347
# Epoch 169/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3877 - accuracy: 0.8430
# Epoch 170/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3796 - accuracy: 0.8554
# Epoch 171/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3795 - accuracy: 0.8512
# Epoch 172/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3869 - accuracy: 0.8430
# Epoch 173/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3845 - accuracy: 0.8512
# Epoch 174/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3823 - accuracy: 0.8430
# Epoch 175/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3955 - accuracy: 0.8347
# Epoch 176/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3950 - accuracy: 0.8388
# Epoch 177/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3884 - accuracy: 0.8347
# Epoch 178/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3942 - accuracy: 0.8347
# Epoch 179/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3877 - accuracy: 0.8388
# Epoch 180/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3798 - accuracy: 0.8595
# Epoch 181/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3816 - accuracy: 0.8554
# Epoch 182/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3849 - accuracy: 0.8347
# Epoch 183/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3782 - accuracy: 0.8595
# Epoch 184/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3792 - accuracy: 0.8512
# Epoch 185/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3774 - accuracy: 0.8636
# Epoch 186/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3898 - accuracy: 0.8388
# Epoch 187/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3820 - accuracy: 0.8388
# Epoch 188/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4012 - accuracy: 0.8140
# Epoch 189/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3848 - accuracy: 0.8347
# Epoch 190/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3822 - accuracy: 0.8471
# Epoch 191/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3723 - accuracy: 0.8554
# Epoch 192/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3834 - accuracy: 0.8512
# Epoch 193/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3744 - accuracy: 0.8512
# Epoch 194/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3847 - accuracy: 0.8471
# Epoch 195/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3696 - accuracy: 0.8595
# Epoch 196/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3750 - accuracy: 0.8554
# Epoch 197/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3841 - accuracy: 0.8306
# Epoch 198/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3950 - accuracy: 0.8182
# Epoch 199/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3806 - accuracy: 0.8471
# Epoch 200/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3791 - accuracy: 0.8512
# Epoch 201/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3775 - accuracy: 0.8347
# Epoch 202/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3807 - accuracy: 0.8512
# Epoch 203/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3735 - accuracy: 0.8595
# Epoch 204/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3727 - accuracy: 0.8636
# Epoch 205/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3806 - accuracy: 0.8388
# Epoch 206/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3810 - accuracy: 0.8388
# Epoch 207/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3690 - accuracy: 0.8512
# Epoch 208/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3676 - accuracy: 0.8636
# Epoch 209/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3698 - accuracy: 0.8719
# Epoch 210/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3663 - accuracy: 0.8512
# Epoch 211/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3770 - accuracy: 0.8512
# Epoch 212/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3670 - accuracy: 0.8471
# Epoch 213/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3712 - accuracy: 0.8554
# Epoch 214/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3669 - accuracy: 0.8471
# Epoch 215/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3706 - accuracy: 0.8595
# Epoch 216/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3737 - accuracy: 0.8471
# Epoch 217/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3817 - accuracy: 0.8347
# Epoch 218/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3822 - accuracy: 0.8264
# Epoch 219/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3726 - accuracy: 0.8595
# Epoch 220/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3728 - accuracy: 0.8430
# Epoch 221/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3704 - accuracy: 0.8636
# Epoch 222/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3740 - accuracy: 0.8512
# Epoch 223/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3658 - accuracy: 0.8719
# Epoch 224/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3749 - accuracy: 0.8471
# Epoch 225/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3701 - accuracy: 0.8595
# Epoch 226/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3701 - accuracy: 0.8471
# Epoch 227/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3660 - accuracy: 0.8595
# Epoch 228/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3659 - accuracy: 0.8512
# Epoch 229/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3616 - accuracy: 0.8554
# Epoch 230/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3706 - accuracy: 0.8595
# Epoch 231/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3661 - accuracy: 0.8430
# Epoch 232/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3658 - accuracy: 0.8678
# Epoch 233/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3634 - accuracy: 0.8554
# Epoch 234/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3623 - accuracy: 0.8554
# Epoch 235/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3621 - accuracy: 0.8554
# Epoch 236/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3631 - accuracy: 0.8554
# Epoch 237/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3660 - accuracy: 0.8678
# Epoch 238/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3634 - accuracy: 0.8471
# Epoch 239/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3818 - accuracy: 0.8512
# Epoch 240/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3634 - accuracy: 0.8554
# Epoch 241/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3637 - accuracy: 0.8636
# Epoch 242/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3643 - accuracy: 0.8595
# Epoch 243/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3688 - accuracy: 0.8512
# Epoch 244/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3628 - accuracy: 0.8595
# Epoch 245/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3613 - accuracy: 0.8554
# Epoch 246/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3658 - accuracy: 0.8512
# Epoch 247/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.8430
# Epoch 248/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3641 - accuracy: 0.8512
# Epoch 249/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3612 - accuracy: 0.8636
# Epoch 250/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3655 - accuracy: 0.8595
# Epoch 251/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3605 - accuracy: 0.8512
# Epoch 252/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3630 - accuracy: 0.8595
# Epoch 253/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3624 - accuracy: 0.8471
# Epoch 254/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3589 - accuracy: 0.8678
# Epoch 255/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3648 - accuracy: 0.8471
# Epoch 256/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3584 - accuracy: 0.8678
# Epoch 257/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3617 - accuracy: 0.8636
# Epoch 258/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3613 - accuracy: 0.8512
# Epoch 259/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3612 - accuracy: 0.8512
# Epoch 260/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3600 - accuracy: 0.8719
# Epoch 261/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3609 - accuracy: 0.8471
# Epoch 262/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3592 - accuracy: 0.8636
# Epoch 263/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3580 - accuracy: 0.8636
# Epoch 264/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3585 - accuracy: 0.8554
# Epoch 265/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3625 - accuracy: 0.8636
# Epoch 266/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3674 - accuracy: 0.8430
# Epoch 267/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3686 - accuracy: 0.8430
# Epoch 268/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3632 - accuracy: 0.8595
# Epoch 269/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3615 - accuracy: 0.8636
# Epoch 270/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3605 - accuracy: 0.8595
# Epoch 271/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3583 - accuracy: 0.8636
# Epoch 272/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3593 - accuracy: 0.8595
# Epoch 273/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3619 - accuracy: 0.8512
# Epoch 274/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3639 - accuracy: 0.8512
# Epoch 275/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3569 - accuracy: 0.8512
# Epoch 276/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3595 - accuracy: 0.8554
# Epoch 277/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3681 - accuracy: 0.8595
# Epoch 278/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3639 - accuracy: 0.8554
# Epoch 279/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3584 - accuracy: 0.8678
# Epoch 280/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3586 - accuracy: 0.8512
# Epoch 281/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3645 - accuracy: 0.8388
# Epoch 282/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3698 - accuracy: 0.8554
# Epoch 283/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3611 - accuracy: 0.8512
# Epoch 284/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3552 - accuracy: 0.8554
# Epoch 285/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3559 - accuracy: 0.8512
# Epoch 286/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3701 - accuracy: 0.8554
# Epoch 287/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3661 - accuracy: 0.8512
# Epoch 288/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3601 - accuracy: 0.8595
# Epoch 289/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3587 - accuracy: 0.8595
# Epoch 290/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3555 - accuracy: 0.8636
# Epoch 291/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3562 - accuracy: 0.8678
# Epoch 292/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3592 - accuracy: 0.8595
# Epoch 293/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3567 - accuracy: 0.8636
# Epoch 294/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3577 - accuracy: 0.8719
# Epoch 295/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3586 - accuracy: 0.8554
# Epoch 296/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3540 - accuracy: 0.8678
# Epoch 297/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3544 - accuracy: 0.8554
# Epoch 298/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3571 - accuracy: 0.8595
# Epoch 299/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3629 - accuracy: 0.8512
# Epoch 300/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3550 - accuracy: 0.8678

# %%
Y_pred_nn = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 12ms/step

# %%
Y_pred_nn.shape
# Out:
# (61, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]

Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")
# Out:
# The accuracy score achieved using Neural Network is: 81.97 %

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x

#print(max_accuracy)
#print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
Y_pred_rf.shape
# Out:
# (61,)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 90.16 %

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost","Neural Network"]

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %
# The accuracy score achieved using Naive Bayes is: 85.25 %
# The accuracy score achieved using Support Vector Machine is: 81.97 %
# The accuracy score achieved using K-Nearest Neighbors is: 67.21 %
# The accuracy score achieved using Decision Tree is: 81.97 %
# The accuracy score achieved using Random Forest is: 90.16 %
# The accuracy score achieved using XGBoost is: 83.61 %
# The accuracy score achieved using Neural Network is: 81.97 %

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(scores)
# Out:
# <Axes: xlabel='Algorithms', ylabel='Accuracy score'>
